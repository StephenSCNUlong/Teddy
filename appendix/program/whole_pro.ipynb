# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import os
import seaborn as sns
import calendar
os.chdir('C:\\Users\\Administrator\\Desktop\\Insane TeddY')

data = pd.read_csv('Pro_Data\\附件1.csv', encoding = 'gbk')
import matplotlib

matplotlib.rcParams['font.sans-serif'] = ['SimHei'] 
matplotlib.rcParams['font.family'] = 'sans-serif'

matplotlib.rcParams['axes.unicode_minus'] = False

#引入数据

print('查看数据列名', data.columns.values.tolist())

commodity5 =  data['商品'][:5]


#前五个数据名
print('前五个商品名称：', commodity5)
print(commodity5.dtypes)


#描述数据

data = data.drop(index = [70679])
des = data[['应付金额', '实际金额']].describe()
print('描述应付与实际金额:', des)
print('总收入:', data['实际金额'].sum())

#把A组提出来
data_A = data.loc[data['地点'] == 'A', :]
data_A.to_csv('task-1A.csv', sep=',')
data_A['支付时间'] = pd.to_datetime(data_A['支付时间'])

#把B组提出来
data_B = data.loc[data['地点'] == 'B', :]
data_B.to_csv('task-1B.csv', sep=',')
data_B['支付时间'] = pd.to_datetime(data_B['支付时间'])

#C组
data_C = data.loc[data['地点'] == 'C', :]
data_C.to_csv('task-1C.csv', sep=',')
data_C['支付时间'] = pd.to_datetime(data_C['支付时间'])

#D组
data_D = data.loc[data['地点'] == 'D', :]
data_D.to_csv('task-1D.csv', sep=',')
data_D['支付时间'] = pd.to_datetime(data_D['支付时间'])

#把E组
data_E = data.loc[data['地点'] == 'E', :]
data_E.to_csv('task-1E.csv', sep=',')
data_E['支付时间'] = pd.to_datetime(data_E['支付时间'])

daA = pd.read_csv('task-1A.csv')
daA
# Out:
# 查看数据列名 ['订单号', '设备ID', '应付金额', '实际金额', '商品', '支付时间', '地点', '状态', '提现']
# 前五个商品名称： 0    68g好丽友巧克力派2枚
# 1      40g双汇玉米热狗肠
# 2       430g泰奇八宝粥
# 3    48g好丽友薯愿香烤原味
# 4       600ml可口可乐
# Name: 商品, dtype: object
# object
# 描述应付与实际金额:                应付金额          实际金额
# count  70679.000000  70679.000000
# mean       4.060325      4.060325
# std        3.357931      3.357931
# min        0.000000      0.000000
# 25%        3.000000      3.000000
# 50%        3.500000      3.500000
# 75%        4.500000      4.500000
# max      125.000000    125.000000
# 总收入: 286979.7
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        Unnamed: 0                               订单号             设备ID  应付金额  \
# 0               1     DD201708167493663555814061164  E43A6E078A04172   3.0
# 1              16     DD201708167493663388737478695  E43A6E078A04172   5.8
# 2              17     DD201708167493663381827746988  E43A6E078A04172   0.8
# 3              20     DD201708167493683503095993712  E43A6E078A04172   3.0
# 4              22     DD2017081110292488D71D623E8F9  E43A6E078A04172   3.5
# 5              24     DD201708167493507701935975302  E43A6E078A04172   3.0
# 6              25     DD2017081018210213E80D235B1C8  E43A6E078A04172   3.0
# 7              31     DD2017081110281595114AF30BC0D  E43A6E078A04172   3.5
# 8              34     DD201708167493662937167036721  E43A6E078A04172   1.5
# 9              37     DD2017052614372337DD5D9082B98  E43A6E078A04172   4.5
# 10             43  DD201708167493000920097772300065  E43A6E078A04172   4.0
# 11             49     DD2017052614334247A1D72F02E30  E43A6E078A04172   2.0
# 12             74     DD201708167493507687358068274  E43A6E078A04172   4.5
# 13             75     DD20170811103326649396032790D  E43A6E078A04172   4.0
# 14             85     DD201708167493662547010881037  E43A6E078A04172   3.0
# 15             92     DD201708167493683259570660391  E43A6E078A04172   2.0
# 16             94     DD2017052616223074032E215F6CA  E43A6E078A04172   3.0
# 17            103     DD201708101523266884F6CA4C7E2  E43A6E078A04172   3.0
# 18            105     DD2017052709451011EA9B9EC6FD5  E43A6E078A04172   1.0
# 19            111     DD201708167493661981689081319  E43A6E078A04172   4.5
# 20            112     DD2017081110210086E681CA92F1C  E43A6E078A04172   3.5
# 21            114     DD201708101516124130A4DB5AF4E  E43A6E078A04172   3.0
# 22            115     DD201708167493507242705902679  E43A6E078A04172   3.5
# 23            120   DD20170816749300299790010723577  E43A6E078A04172   1.8
# 24            126   DD20170816749300338025192860536  E43A6E078A04172   6.0
# 25            134     DD201708167493669401533300035  E43A6E078A04172   8.0
# 26            139      DD20170816749366937728453747  E43A6E078A04172   7.0
# 27            144   DD20170816749300412660581879242  E43A6E078A04172   6.0
# 28            157    DD2017081674930737246106122382  E43A6E078A04172   2.5
# 29            163     DD2017052616015557A759E716CE4  E43A6E078A04172   3.0
# ...           ...                               ...              ...   ...
# 10456       70477     DD201708167493358835724493757  E43A6E078A04172   2.5
# 10457       70481     DD20170425132731416C58E92E2C8  E43A6E078A04172   4.5
# 10458       70484     DD2017042512174281AAB617B3BDF  E43A6E078A04172   4.5
# 10459       70487     DD201708167493358141621347788  E43A6E078A04172   5.5
# 10460       70490     DD2017042512043519B5BE02EFCBB  E43A6E078A04172   4.5
# 10461       70505     DD201708167493357170265374163  E43A6E078A04172   0.8
# 10462       70509     DD201708167493322027244011228  E43A6E078A04172   3.5
# 10463       70510     DD20170428062825730D4F766B26D  E43A6E078A04172   4.0
# 10464       70513     DD201708167493357062357246595  E43A6E078A04172   8.0
# 10465       70515     DD201708167493414244262723617  E43A6E078A04172   4.5
# 10466       70516     DD20170425020503542CD2FBCA983  E43A6E078A04172   4.5
# 10467       70520     DD201708167493356760726009143  E43A6E078A04172   4.5
# 10468       70524     DD201708167493377737837028982  E43A6E078A04172   7.5
# 10469       70527     DD201708167493377538508987421  E43A6E078A04172   4.5
# 10470       70530     DD201706010747298809525AA5911  E43A6E078A04172   4.0
# 10471       70531     DD201708301505134782FA481E2D3  E43A6E078A04172   2.5
# 10472       70533     DD20170601074802750DCA14D90CB  E43A6E078A04172   4.0
# 10473       70537     DD20170614075659886224412FC35  E43A6E078A04172   4.0
# 10474       70540      DD20170816749357510993523708  E43A6E078A04172   4.5
# 10475       70585     DD20170613214950494DD6C7F7A18  E43A6E078A04172  15.0
# 10476       70591     DD201708167493572504872595939  E43A6E078A04172   6.0
# 10477       70613     DD20170601173623647D71A3AE1DB  E43A6E078A04172   2.5
# 10478       70619     DD2017060118413946EF05A15CCBB  E43A6E078A04172   3.0
# 10479       70629     DD2017083102101642636A6A37289  E43A6E078A04172   3.0
# 10480       70645     DD2017060120573277986E98D411C  E43A6E078A04172   2.0
# 10481       70652     DD2017060302425773B4D65F312AA  E43A6E078A04172   4.0
# 10482       70657     DD2017061311052846B82DC78698F  E43A6E078A04172   3.5
# 10483       70662     DD2017060301194538AA399AA5454  E43A6E078A04172   3.5
# 10484       70669     DD2017061307481075B0D896C6185  E43A6E078A04172   1.5
# 10485       70673     DD2017060214264174BB258F3CAA0  E43A6E078A04172   4.5
#
#        实际金额                     商品              支付时间 地点      状态   提现
# 0       3.0             40g双汇玉米热狗肠     2017/1/1 1:33  A  已出货未退款  已提现
# 1       5.8         100g卫龙点心面黑椒牛排味    2017/1/1 19:29  A  已出货未退款  已提现
# 2       0.8             咪咪虾条马来西亚风味    2017/1/1 19:33  A  已出货未退款  已提现
# 3       3.0             250ml维他柠檬茶    2017/1/1 19:55  A  已出货未退款  已提现
# 4       3.5                   东鹏特饮    2017/1/1 20:18  A  已出货未退款  已提现
# 5       3.0             250ml维他柠檬茶    2017/1/1 20:25  A  已出货未退款  已提现
# 6       3.0                  卫龙大面筋    2017/1/1 20:25  A  已出货未退款  已提现
# 7       3.5                   东鹏特饮     2017/1/2 8:50  A  已出货未退款  已提现
# 8       1.5             卫龙亲嘴烧红烧牛肉味    2017/1/2 12:02  A  已出货未退款  已提现
# 9       4.5                  阿萨姆奶茶    2017/1/2 13:34  A  已出货未退款  已提现
# 10      4.0            145ml旺仔牛奶盒装    2017/1/2 13:58  A  已出货未退款  已提现
# 11      2.0                  伊利优酸乳    2017/1/2 15:56  A  已出货未退款  已提现
# 12      4.5               2g韩国海牌海苔    2017/1/2 22:42  A  已出货未退款  已提现
# 13      4.0                     脉动    2017/1/2 22:42  A  已出货未退款  已提现
# 14      3.0             250ml维他柠檬茶     2017/1/3 9:50  A  已出货未退款  已提现
# 15      2.0  75g新麦潮天然酵母面包（北海道牛奶风味）    2017/1/3 14:57  A  已出货未退款  已提现
# 16      3.0                可口可乐最新款    2017/1/3 15:10  A  已出货未退款  已提现
# 17      3.0                    果粒橙    2017/1/3 15:44  A  已出货未退款  已提现
# 18      1.0                    香豆干    2017/1/3 15:46  A  已出货未退款  已提现
# 19      4.5             78g卫龙亲嘴语辣条    2017/1/3 16:23  A  已出货未退款  已提现
# 20      3.5                   东鹏特饮    2017/1/3 16:24  A  已出货未退款  已提现
# 21      3.0                    果粒橙    2017/1/3 16:25  A  已出货未退款  已提现
# 22      3.5                   可乐可乐    2017/1/3 16:25  A  已出货未退款  已提现
# 23      1.8               32g卫龙亲嘴烧    2017/1/3 20:24  A  已出货未退款  已提现
# 24      6.0             250ml维他柠檬茶     2017/1/4 0:29  A  已出货未退款  已提现
# 25      8.0            80g四洲粟一烧烧烤味     2017/1/4 8:58  A  已出货未退款  已提现
# 26      7.0             86g合味道浓猪骨味     2017/1/4 9:00  A  已出货未退款  已提现
# 27      6.0         330ml伊利畅意乳酸菌原味    2017/1/4 13:50  A  已出货未退款  已提现
# 28      2.5               14g德芙巧克力    2017/1/5 14:54  A  已出货未退款  已提现
# 29      3.0                   统一绿茶    2017/1/5 16:02  A  已出货未退款  已提现
# ...     ...                    ...               ... ..     ...  ...
# 10456   2.5            30g无穷农场盐_鸡蛋  2017/12/30 12:00  A  已出货未退款  已提现
# 10457   4.5                     脉动  2017/12/30 13:14  A  已出货未退款  已提现
# 10458   4.5                     脉动  2017/12/30 13:57  A  已出货未退款  已提现
# 10459   5.5          268ml雀巢咖啡丝滑拿铁  2017/12/30 14:19  A  已出货未退款  已提现
# 10460   4.5                     脉动  2017/12/30 15:41  A  已出货未退款  已提现
# 10461   0.8             20g咩咩世界虾味条  2017/12/30 16:51  A  已出货未退款  已提现
# 10462   3.5        85g新麦潮手撕面包（提子味）  2017/12/30 17:06  A  已出货未退款  已提现
# 10463   4.0                阿萨姆煎茶奶绿  2017/12/30 17:19  A  已出货未退款  已提现
# 10464   8.0     20g马来西亚风味咪咪蟹味粒0219  2017/12/30 18:03  A  已出货未退款  已提现
# 10465   4.5            250ml燕塘红枣牛奶  2017/12/30 18:24  A  已出货未退款  已提现
# 10466   4.5                  阿萨姆奶茶  2017/12/30 18:24  A  已出货未退款  已提现
# 10467   4.5             250ml燕塘甜牛奶  2017/12/30 19:29  A  已出货未退款  已提现
# 10468   7.5                     红牛  2017/12/30 19:38  A  已出货未退款  已提现
# 10469   4.5             40g上好佳日式鱼果  2017/12/30 20:08  A  已出货未退款  已提现
# 10470   4.0                   东鹏特饮   2017/12/31 0:35  A  已出货未退款  已提现
# 10471   2.5                  雪碧最新款   2017/12/31 0:36  A  已出货未退款  已提现
# 10472   4.0                   东鹏特饮   2017/12/31 0:59  A  已出货未退款  已提现
# 10473   4.0                     脉动   2017/12/31 2:07  A  已出货未退款  已提现
# 10474   4.5            500ml营养快线原味   2017/12/31 2:11  A  已出货未退款  已提现
# 10475  15.0               口味王槟榔（红）  2017/12/31 12:06  A  已出货未退款  已提现
# 10476   6.0             250ml维他柠檬茶  2017/12/31 13:27  A  已出货未退款  已提现
# 10477   2.5                  伊利优酸乳  2017/12/31 14:54  A  已出货未退款  已提现
# 10478   3.0              雪碧（500ml）  2017/12/31 15:08  A  已出货未退款  已提现
# 10479   3.0                   统一绿茶  2017/12/31 15:35  A  已出货未退款  已提现
# 10480   2.0                  怡宝纯净水  2017/12/31 17:09  A  已出货未退款  已提现
# 10481   4.0                   营养快线  2017/12/31 17:39  A  已出货未退款  已提现
# 10482   3.5                   东鹏特饮  2017/12/31 18:27  A  已出货未退款  已提现
# 10483   3.5                  雪碧最新款  2017/12/31 20:05  A  已出货未退款  已提现
# 10484   1.5                    香豆干  2017/12/31 20:22  A  已出货未退款  已提现
# 10485   4.5                   营养快线  2017/12/31 21:51  A  已出货未退款  已提现
#
# [10486 rows x 10 columns]

# %%
print(data_A.describe())
print('A的交易总额', data_A['应付金额'].sum(),'订单量：', data_A['应付金额'].count(), '每单均值：', data_A['应付金额'].sum()/data_A['应付金额'].count())
print(data_B.describe())
print('B的交易总额', data_B['应付金额'].sum(),'订单量：', data_B['应付金额'].count(), '每单均值：', data_B['应付金额'].sum()/data_B['应付金额'].count())
print(data_C.describe())
print('C的交易总额', data_C['应付金额'].sum(),'订单量：', data_C['应付金额'].count(), '每单均值：', data_C['应付金额'].sum()/data_C['应付金额'].count())
print(data_D.describe())
print('D的交易总额', data_D['应付金额'].sum(),'订单量：', data_D['应付金额'].count(), '每单均值：', data_D['应付金额'].sum()/data_D['应付金额'].count())
print(data_E.describe())
print('E的交易总额', data_E['应付金额'].sum(),'订单量：', data_E['应付金额'].count(), '每单均值：', data_E['应付金额'].sum()/data_E['应付金额'].count())
# Out:
#                应付金额          实际金额
# count  10486.000000  10486.000000
# mean       4.057086      4.057086
# std        3.346493      3.346493
# min        0.000000      0.000000
# 25%        2.500000      2.500000
# 50%        3.500000      3.500000
# 75%        4.500000      4.500000
# max      100.000000    100.000000
# A的交易总额 42542.6 订单量： 10486 每单均值： 4.057085637993515
#                应付金额          实际金额
# count  13482.000000  13482.000000
# mean       4.003138      4.003138
# std        3.617798      3.617798
# min        0.000000      0.000000
# 25%        3.000000      3.000000
# 50%        3.500000      3.500000
# 75%        4.500000      4.500000
# max      125.000000    125.000000
# B的交易总额 53970.3 订单量： 13482 每单均值： 4.003137516688919
#                应付金额          实际金额
# count  14493.000000  14493.000000
# mean       4.248127      4.248127
# std        3.783290      3.783290
# min        0.000000      0.000000
# 25%        3.000000      3.000000
# 50%        3.500000      3.500000
# 75%        4.500000      4.500000
# max      112.500000    112.500000
# C的交易总额 61568.1 订单量： 14493 每单均值： 4.248126681846409
#               应付金额         实际金额
# count  8713.000000  8713.000000
# mean      3.815368     3.815368
# std       2.840134     2.840134
# min       0.000000     0.000000
# 25%       3.000000     3.000000
# 50%       3.000000     3.000000
# 75%       4.000000     4.000000
# max      60.500000    60.500000
# D的交易总额 33243.299999999996 订单量： 8713 每单均值： 3.8153678411568914
#                应付金额          实际金额
# count  23505.000000  23505.000000
# mean       4.069577      4.069577
# std        3.089145      3.089145
# min        0.000000      0.000000
# 25%        3.000000      3.000000
# 50%        3.500000      3.500000
# 75%        4.500000      4.500000
# max      112.500000    112.500000
# E的交易总额 95655.4 订单量： 23505 每单均值： 4.069576685811529

# %%
#A组五月份数据
May_1 = data_A.ix[pd.to_datetime('2017/4/30 23:59') < data_A['支付时间'] , :]
May_A = May_1.ix[ May_1['支付时间'] < pd.to_datetime('2017/6/1 00:00') , :]
print(May_A.describe())
print('A的交易总额', May_A['应付金额'].sum())

#B组五月份数据
May_1 = data_B.ix[pd.to_datetime('2017/4/30 23:59') < data_B['支付时间'] , :]
May_B = May_1.ix[ May_1['支付时间'] < pd.to_datetime('2017/6/1 00:00') , :]
print(May_B.describe())
print('B的交易总额', May_B['应付金额'].sum())

#5月提取
May_1 = data_C.ix[pd.to_datetime('2017/4/30 23:59') < data_C['支付时间'] , :]
May_C = May_1.ix[ May_1['支付时间'] < pd.to_datetime('2017/6/1 00:00') , :]
print(May_C.describe())
print('C的交易总额', May_C['应付金额'].sum())

#D组五月份数据
May_1 = data_D.ix[pd.to_datetime('2017/4/30 23:59') < data_D['支付时间'] , :]
May_D = May_1.ix[ May_1['支付时间'] < pd.to_datetime('2017/6/1 00:00') , :]
print(May_D.describe())
print('D的交易总额', May_D['应付金额'].sum())

#E组五月份数据
May_1 = data_E.ix[pd.to_datetime('2017/4/30 23:59') < data_E['支付时间'] , :]
May_E = May_1.ix[ May_1['支付时间'] < pd.to_datetime('2017/6/1 00:00') , :]
print(May_E.describe())
print('E的交易总额', May_E['应付金额'].sum())
# Out:
#              应付金额        实际金额
# count  756.000000  756.000000
# mean     4.477646    4.477646
# std      3.909918    3.909918
# min      0.000000    0.000000
# 25%      3.000000    3.000000
# 50%      4.000000    4.000000
# 75%      5.000000    5.000000
# max     51.000000   51.000000
# A的交易总额 3385.1
#              应付金额        实际金额
# count  869.000000  869.000000
# mean     4.236133    4.236133
# std      3.459750    3.459750
# min      0.000000    0.000000
# 25%      3.000000    3.000000
# 50%      3.500000    3.500000
# 75%      5.000000    5.000000
# max     72.000000   72.000000
# B的交易总额 3681.2
#              应付金额        实际金额
# count  789.000000  789.000000
# mean     4.726743    4.726743
# std      4.376356    4.376356
# min      0.000000    0.000000
# 25%      3.000000    3.000000
# 50%      4.000000    4.000000
# 75%      5.500000    5.500000
# max     72.000000   72.000000
# C的交易总额 3729.4
#              应付金额        实际金额
# count  564.000000  564.000000
# mean     4.241312    4.241312
# std      3.146491    3.146491
# min      0.000000    0.000000
# 25%      2.500000    2.500000
# 50%      3.500000    3.500000
# 75%      4.500000    4.500000
# max     25.000000   25.000000
# D的交易总额 2392.1
#               应付金额         实际金额
# count  1292.000000  1292.000000
# mean      4.410991     4.410991
# std       3.021052     3.021052
# min       0.000000     0.000000
# 25%       3.000000     3.000000
# 50%       3.500000     3.500000
# 75%       5.500000     5.500000
# max      54.500000    54.500000
# E的交易总额 5699.0
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # This is added back by InteractiveShellApp.init_path()
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   app.launch_new_instance()
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:28: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
print('##################################分割线################')
group_ABCD = data.groupby('地点')
print(type(group_ABCD))

print(group_ABCD.size())
# Out:
# ##################################分割线################
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# 地点
# A    10486
# B    13482
# C    14493
# D     8713
# E    23505
# dtype: int64

# %%
print(group_ABCD['实际金额'])
# Out:
# <pandas.core.groupby.generic.SeriesGroupBy object at 0x0000000018BB36D8>

# %%
group_SUM = group_ABCD['实际金额'].sum()
print(group_SUM)
# Out:
# 地点
# A    42542.6
# B    53970.3
# C    61568.1
# D    33243.3
# E    95655.4
# Name: 实际金额, dtype: float64

# %%
#以下计算计算每台售货机2017年5月的交易额、订单量以及所有售货机交易总额和订单总量，以表格形式体现在报告中（作为月销售的例子）
print(May_A.describe())
print('A在5月份的订单量：', len(May_A),""" """ ,'订单总额：', May_A['实际金额'].sum())
print(May_B.describe())
print('B在5月份的订单量：', len(May_B),""" """ ,'订单总额：', May_B['实际金额'].sum())
print(May_C.describe())
print('C在5月份的订单量：', len(May_C),""" """ ,'订单总额：', May_C['实际金额'].sum())
print(May_D.describe())
print('D在5月份的订单量：', len(May_D),""" """ ,'订单总额：', May_D['实际金额'].sum())
print(May_E.describe())
print('E在5月份的订单量：', len(May_E),""" """ ,'订单总额：', May_E['实际金额'].sum())
# Out:
#              应付金额        实际金额
# count  756.000000  756.000000
# mean     4.477646    4.477646
# std      3.909918    3.909918
# min      0.000000    0.000000
# 25%      3.000000    3.000000
# 50%      4.000000    4.000000
# 75%      5.000000    5.000000
# max     51.000000   51.000000
# A在5月份的订单量： 756   订单总额： 3385.1
#              应付金额        实际金额
# count  869.000000  869.000000
# mean     4.236133    4.236133
# std      3.459750    3.459750
# min      0.000000    0.000000
# 25%      3.000000    3.000000
# 50%      3.500000    3.500000
# 75%      5.000000    5.000000
# max     72.000000   72.000000
# B在5月份的订单量： 869   订单总额： 3681.2
#              应付金额        实际金额
# count  789.000000  789.000000
# mean     4.726743    4.726743
# std      4.376356    4.376356
# min      0.000000    0.000000
# 25%      3.000000    3.000000
# 50%      4.000000    4.000000
# 75%      5.500000    5.500000
# max     72.000000   72.000000
# C在5月份的订单量： 789   订单总额： 3729.4
#              应付金额        实际金额
# count  564.000000  564.000000
# mean     4.241312    4.241312
# std      3.146491    3.146491
# min      0.000000    0.000000
# 25%      2.500000    2.500000
# 50%      3.500000    3.500000
# 75%      4.500000    4.500000
# max     25.000000   25.000000
# D在5月份的订单量： 564   订单总额： 2392.1
#               应付金额         实际金额
# count  1292.000000  1292.000000
# mean      4.410991     4.410991
# std       3.021052     3.021052
# min       0.000000     0.000000
# 25%       3.000000     3.000000
# 50%       3.500000     3.500000
# 75%       5.500000     5.500000
# max      54.500000    54.500000
# E在5月份的订单量： 1292   订单总额： 5699.0

# %%
#以下计算计算每台售货机2017年5月的交易额、订单量以及所有售货机交易总额和订单总量，以表格形式体现在报告中（作为月销售的例子）
print(data_A.describe())
print('A在2017年的订单量：', len(data_A),""" """ ,'订单总额：', data_A['实际金额'].sum())
print(data_B.describe())
print('B在2017年的订单量：', len(data_B),""" """ ,'订单总额：', data_B['实际金额'].sum())
print(data_C.describe())
print('C在2017年的订单量：', len(data_C),""" """ ,'订单总额：', data_C['实际金额'].sum())
print(data_D.describe())
print('D在2017年的订单量：', len(data_D),""" """ ,'订单总额：', data_D['实际金额'].sum().astype('float32'))
print(data_E.describe())
print('E在2017年的订单量：', len(data_E),""" """ ,'订单总额：', data_E['实际金额'].sum())
# Out:
#                应付金额          实际金额
# count  10486.000000  10486.000000
# mean       4.057086      4.057086
# std        3.346493      3.346493
# min        0.000000      0.000000
# 25%        2.500000      2.500000
# 50%        3.500000      3.500000
# 75%        4.500000      4.500000
# max      100.000000    100.000000
# A在2017年的订单量： 10486   订单总额： 42542.6
#                应付金额          实际金额
# count  13482.000000  13482.000000
# mean       4.003138      4.003138
# std        3.617798      3.617798
# min        0.000000      0.000000
# 25%        3.000000      3.000000
# 50%        3.500000      3.500000
# 75%        4.500000      4.500000
# max      125.000000    125.000000
# B在2017年的订单量： 13482   订单总额： 53970.3
#                应付金额          实际金额
# count  14493.000000  14493.000000
# mean       4.248127      4.248127
# std        3.783290      3.783290
# min        0.000000      0.000000
# 25%        3.000000      3.000000
# 50%        3.500000      3.500000
# 75%        4.500000      4.500000
# max      112.500000    112.500000
# C在2017年的订单量： 14493   订单总额： 61568.1
#               应付金额         实际金额
# count  8713.000000  8713.000000
# mean      3.815368     3.815368
# std       2.840134     2.840134
# min       0.000000     0.000000
# 25%       3.000000     3.000000
# 50%       3.000000     3.000000
# 75%       4.000000     4.000000
# max      60.500000    60.500000
# D在2017年的订单量： 8713   订单总额： 33243.3
#                应付金额          实际金额
# count  23505.000000  23505.000000
# mean       4.069577      4.069577
# std        3.089145      3.089145
# min        0.000000      0.000000
# 25%        3.000000      3.000000
# 50%        3.500000      3.500000
# 75%        4.500000      4.500000
# max      112.500000    112.500000
# E在2017年的订单量： 23505   订单总额： 95655.4

# %%
#售货机每月交易额
AMON = []
BMON = []
CMON = []
DMON = []
EMON = []
avg_A = []
avg_B = []
avg_C = []
avg_D = []
avg_E = []
avgDay_A = []
avgDay_B = []
avgDay_C = []
avgDay_D = []
avgDay_E = []


for j in range(1,13):
        data_A_month = data_A[data_A['支付时间'].dt.month == j]
        data_B_month = data_B[data_B['支付时间'].dt.month == j]
        data_C_month = data_C[data_C['支付时间'].dt.month == j]
        data_D_month = data_D[data_D['支付时间'].dt.month == j]
        data_E_month = data_E[data_E['支付时间'].dt.month == j]
        print('this is ', j , 'th month:')
        import calendar
        nu, monthRange = calendar.monthrange(2017,j)
        
        #print(data_A_month.describe())
        print('A在2017年第',j ,'月的订单量：', len(data_A_month),""" """ ,'订单总额：', data_A_month['实际金额'].sum().astype('float32'))
        avg = data_A_month['实际金额'].sum().astype('float32') / len(data_A_month)
        avg = avg.astype('float32')
        print('平均每单交易额为:', avg )
        avg_A.append(avg)
        avgDay = len(data_A_month) / monthRange
        print('日均订单量：', avgDay)
        avgDay_A.append(avgDay)
        
        print('B在2017年第',j ,'月的订单量：', len(data_B_month),""" """ ,'订单总额：', data_B_month['实际金额'].sum().astype('float32'))
        avg = data_B_month['实际金额'].sum().astype('float32') / len(data_B_month)
        avg = avg.astype('float32')
        print('平均每单交易额为:', avg )
        avg_B.append(avg)
        avgDay = len(data_B_month) / monthRange
        print('日均订单量：', avgDay)
        avgDay_B.append(avgDay)
        
        
        print('C在2017年第',j ,'月的订单量：', len(data_C_month),""" """ ,'订单总额：', data_C_month['实际金额'].sum().astype('float32'))
        avg = data_C_month['实际金额'].sum().astype('float32') / len(data_C_month)
        avg = avg.astype('float32')
        print('平均每单交易额为:', avg )
        avg_C.append(avg)
        avgDay = len(data_C_month) / monthRange
        print('日均订单量：', avgDay)
        avgDay_C.append(avgDay)
        
        print('D在2017年第',j ,'月的订单量：', len(data_D_month),""" """ ,'订单总额：', data_D_month['实际金额'].sum().astype('float32'))
        avg = data_D_month['实际金额'].sum().astype('float32') / len(data_D_month)
        avg = avg.astype('float32')
        print('平均每单交易额为:', avg )
        avg_D.append(avg)
        avgDay = len(data_D_month) / monthRange
        print('日均订单量：', avgDay)
        avgDay_D.append(avgDay)
        
        print('E在2017年第',j ,'月的订单量：', len(data_E_month),""" """ ,'订单总额：', data_E_month['实际金额'].sum().astype('float32'))
        avg = data_E_month['实际金额'].sum().astype('float32') / len(data_E_month)
        avg = avg.astype('float32')
        print('平均每单交易额为:', avg )
        avg_E.append(avg)
        avgDay = len(data_E_month) / monthRange
        print('日均订单量：', avgDay)
        avgDay_E.append(avgDay)
        print("""  """)
        
        
        AMON.append(data_A_month['实际金额'].sum().astype('float32'))
        BMON.append(data_B_month['实际金额'].sum().astype('float32'))
        CMON.append(data_C_month['实际金额'].sum().astype('float32'))
        DMON.append(data_D_month['实际金额'].sum().astype('float32'))
        EMON.append(data_E_month['实际金额'].sum().astype('float32'))
        
print(AMON)
print(BMON)
print(CMON)
print(DMON)
print(EMON)
print(avg_A)
# Out:
# this is  1 th month:
# A在2017年第 1 月的订单量： 335   订单总额： 1509.7
# 平均每单交易额为: 4.506567
# 日均订单量： 10.806451612903226
# B在2017年第 1 月的订单量： 366   订单总额： 1373.6
# 平均每单交易额为: 3.7530055
# 日均订单量： 11.806451612903226
# C在2017年第 1 月的订单量： 379   订单总额： 1640.5
# 平均每单交易额为: 4.328496
# 日均订单量： 12.225806451612904
# D在2017年第 1 月的订单量： 259   订单总额： 956.4
# 平均每单交易额为: 3.6926641
# 日均订单量： 8.35483870967742
# E在2017年第 1 月的订单量： 354   订单总额： 1656.8
# 平均每单交易额为: 4.6802263
# 日均订单量： 11.419354838709678
#
# this is  2 th month:
# A在2017年第 2 月的订单量： 114   订单总额： 440.5
# 平均每单交易额为: 3.8640351
# 日均订单量： 4.071428571428571
# B在2017年第 2 月的订单量： 185   订单总额： 602.3
# 平均每单交易额为: 3.2556756
# 日均订单量： 6.607142857142857
# C在2017年第 2 月的订单量： 207   订单总额： 792.0
# 平均每单交易额为: 3.826087
# 日均订单量： 7.392857142857143
# D在2017年第 2 月的订单量： 141   订单总额： 435.5
# 平均每单交易额为: 3.0886524
# 日均订单量： 5.035714285714286
# E在2017年第 2 月的订单量： 258   订单总额： 938.7
# 平均每单交易额为: 3.6383722
# 日均订单量： 9.214285714285714
#
# this is  3 th month:
# A在2017年第 3 月的订单量： 255   订单总额： 914.3
# 平均每单交易额为: 3.5854902
# 日均订单量： 8.225806451612904
# B在2017年第 3 月的订单量： 265   订单总额： 957.9
# 平均每单交易额为: 3.614717
# 日均订单量： 8.548387096774194
# C在2017年第 3 月的订单量： 263   订单总额： 991.5
# 平均每单交易额为: 3.769962
# 日均订单量： 8.483870967741936
# D在2017年第 3 月的订单量： 192   订单总额： 826.7
# 平均每单交易额为: 4.3057294
# 日均订单量： 6.193548387096774
# E在2017年第 3 月的订单量： 350   订单总额： 1507.0
# 平均每单交易额为: 4.305714
# 日均订单量： 11.290322580645162
#
# this is  4 th month:
# A在2017年第 4 月的订单量： 447   订单总额： 1804.5
# 平均每单交易额为: 4.036913
# 日均订单量： 14.9
# B在2017年第 4 月的订单量： 603   订单总额： 2457.4
# 平均每单交易额为: 4.07529
# 日均订单量： 20.1
# C在2017年第 4 月的订单量： 734   订单总额： 3232.3
# 平均每单交易额为: 4.4036784
# 日均订单量： 24.466666666666665
# D在2017年第 4 月的订单量： 443   订单总额： 1679.1
# 平均每单交易额为: 3.7902935
# 日均订单量： 14.766666666666667
# E在2017年第 4 月的订单量： 895   订单总额： 3723.1
# 平均每单交易额为: 4.1598883
# 日均订单量： 29.833333333333332
#
# this is  5 th month:
# A在2017年第 5 月的订单量： 756   订单总额： 3385.1
# 平均每单交易额为: 4.4776454
# 日均订单量： 24.387096774193548
# B在2017年第 5 月的订单量： 869   订单总额： 3681.2
# 平均每单交易额为: 4.2361336
# 日均订单量： 28.032258064516128
# C在2017年第 5 月的订单量： 789   订单总额： 3729.4
# 平均每单交易额为: 4.7267427
# 日均订单量： 25.451612903225808
# D在2017年第 5 月的订单量： 564   订单总额： 2392.1
# 平均每单交易额为: 4.241312
# 日均订单量： 18.193548387096776
# E在2017年第 5 月的订单量： 1292   订单总额： 5699.0
# 平均每单交易额为: 4.4109907
# 日均订单量： 41.67741935483871
#
# this is  6 th month:
# A在2017年第 6 月的订单量： 1669   订单总额： 6755.1
# 平均每单交易额为: 4.047394
# 日均订单量： 55.63333333333333
# B在2017年第 6 月的订单量： 1856   订单总额： 7550.3
# 平均每单交易额为: 4.0680494
# 日均订单量： 61.86666666666667
# C在2017年第 6 月的订单量： 1882   订单总额： 8472.2
# 平均每单交易额为: 4.5017004
# 日均订单量： 62.733333333333334
# D在2017年第 6 月的订单量： 1040   订单总额： 4187.0
# 平均每单交易额为: 4.0259614
# 日均订单量： 34.666666666666664
# E在2017年第 6 月的订单量： 2593   订单总额： 9899.7
# 平均每单交易额为: 3.8178558
# 日均订单量： 86.43333333333334
#
# this is  7 th month:
# A在2017年第 7 月的订单量： 476   订单总额： 1950.5
# 平均每单交易额为: 4.097689
# 日均订单量： 15.35483870967742
# B在2017年第 7 月的订单量： 345   订单总额： 1518.6
# 平均每单交易额为: 4.401739
# 日均订单量： 11.129032258064516
# C在2017年第 7 月的订单量： 764   订单总额： 3047.1
# 平均每单交易额为: 3.9883509
# 日均订单量： 24.64516129032258
# D在2017年第 7 月的订单量： 317   订单总额： 1340.8
# 平均每单交易额为: 4.2296534
# 日均订单量： 10.225806451612904
# E在2017年第 7 月的订单量： 813   订单总额： 3186.4
# 平均每单交易额为: 3.919311
# 日均订单量： 26.225806451612904
#
# this is  8 th month:
# A在2017年第 8 月的订单量： 666   订单总额： 2236.9
# 平均每单交易额为: 3.3587086
# 日均订单量： 21.483870967741936
# B在2017年第 8 月的订单量： 981   订单总额： 3516.1
# 平均每单交易额为: 3.5842
# 日均订单量： 31.64516129032258
# C在2017年第 8 月的订单量： 1259   订单总额： 4927.2
# 平均每单交易额为: 3.9135823
# 日均订单量： 40.61290322580645
# D在2017年第 8 月的订单量： 715   订单总额： 2371.3
# 平均每单交易额为: 3.3165035
# 日均订单量： 23.06451612903226
# E在2017年第 8 月的订单量： 1767   订单总额： 6722.5
# 平均每单交易额为: 3.8044708
# 日均订单量： 57.0
#
# this is  9 th month:
# A在2017年第 9 月的订单量： 1040   订单总额： 4479.5
# 平均每单交易额为: 4.3072114
# 日均订单量： 34.666666666666664
# B在2017年第 9 月的订单量： 1745   订单总额： 7207.3
# 平均每单交易额为: 4.1302576
# 日均订单量： 58.166666666666664
# C在2017年第 9 月的订单量： 1678   订单总额： 7429.0
# 平均每单交易额为: 4.4272943
# 日均订单量： 55.93333333333333
# D在2017年第 9 月的订单量： 983   订单总额： 3833.1
# 平均每单交易额为: 3.8993897
# 日均订单量： 32.766666666666666
# E在2017年第 9 月的订单量： 4134   订单总额： 17054.3
# 平均每单交易额为: 4.1253753
# 日均订单量： 137.8
#
# this is  10 th month:
# A在2017年第 10 月的订单量： 1565   订单总额： 6292.4
# 平均每单交易额为: 4.020703
# 日均订单量： 50.483870967741936
# B在2017年第 10 月的订单量： 2026   订单总额： 8331.6
# 平均每单交易额为: 4.1123395
# 日均订单量： 65.35483870967742
# C在2017年第 10 月的订单量： 2216   订单总额： 9469.7
# 平均每单交易额为: 4.27333
# 日均订单量： 71.48387096774194
# D在2017年第 10 月的订单量： 1186   订单总额： 4606.7
# 平均每单交易额为: 3.884233
# 日均订单量： 38.25806451612903
# E在2017年第 10 月的订单量： 2777   订单总额： 10208.6
# 平均每单交易额为: 3.6761253
# 日均订单量： 89.58064516129032
#
# this is  11 th month:
# A在2017年第 11 月的订单量： 1160   订单总额： 5187.0
# 平均每单交易额为: 4.471552
# 日均订单量： 38.666666666666664
# B在2017年第 11 月的订单量： 2031   订单总额： 8669.9
# 平均每单交易额为: 4.268784
# 日均订单量： 67.7
# C在2017年第 11 月的订单量： 1943   订单总额： 8456.7
# 平均每单交易额为: 4.352393
# 日均订单量： 64.76666666666667
# D在2017年第 11 月的订单量： 1210   订单总额： 4673.4
# 平均每单交易额为: 3.862314
# 日均订单量： 40.333333333333336
# E在2017年第 11 月的订单量： 5020   订单总额： 21501.8
# 平均每单交易额为: 4.2832274
# 日均订单量： 167.33333333333334
#
# this is  12 th month:
# A在2017年第 12 月的订单量： 2003   订单总额： 7587.1
# 平均每单交易额为: 3.7878683
# 日均订单量： 64.61290322580645
# B在2017年第 12 月的订单量： 2210   订单总额： 8104.1
# 平均每单交易额为: 3.6670136
# 日均订单量： 71.29032258064517
# C在2017年第 12 月的订单量： 2379   订单总额： 9380.5
# 平均每单交易额为: 3.9430432
# 日均订单量： 76.74193548387096
# D在2017年第 12 月的订单量： 1663   订单总额： 5941.2
# 平均每单交易额为: 3.5725799
# 日均订单量： 53.645161290322584
# E在2017年第 12 月的订单量： 3252   订单总额： 13557.5
# 平均每单交易额为: 4.168973
# 日均订单量： 104.90322580645162
#
# [1509.7, 440.5, 914.3, 1804.5, 3385.1, 6755.1, 1950.5, 2236.9, 4479.5, 6292.4, 5187.0, 7587.1]
# [1373.6, 602.3, 957.9, 2457.4, 3681.2, 7550.3, 1518.6, 3516.1, 7207.3, 8331.6, 8669.9, 8104.1]
# [1640.5, 792.0, 991.5, 3232.3, 3729.4, 8472.2, 3047.1, 4927.2, 7429.0, 9469.7, 8456.7, 9380.5]
# [956.4, 435.5, 826.7, 1679.1, 2392.1, 4187.0, 1340.8, 2371.3, 3833.1, 4606.7, 4673.4, 5941.2]
# [1656.8, 938.7, 1507.0, 3723.1, 5699.0, 9899.7, 3186.4, 6722.5, 17054.3, 10208.6, 21501.8, 13557.5]
# [4.506567, 3.8640351, 3.5854902, 4.036913, 4.4776454, 4.047394, 4.097689, 3.3587086, 4.3072114, 4.020703, 4.471552, 3.7878683]

# %%
data_A_Jun = data_A[data_A['支付时间'].dt.month == 5]
good_A_Jun =data_A_Jun['商品'].value_counts()
AJ = good_A_Jun.head(5)

print('###########')
data_B_Jun = data_B[data_B['支付时间'].dt.month == 5]
good_B_Jun =data_B_Jun['商品'].value_counts()
BJ = good_B_Jun.head(5)

print('###########')
data_C_Jun = data_C[data_C['支付时间'].dt.month == 5]
good_C_Jun =data_C_Jun['商品'].value_counts()
CJ = good_C_Jun.head(5)

print('###########')
data_D_Jun = data_D[data_D['支付时间'].dt.month == 5]
good_D_Jun =data_D_Jun['商品'].value_counts()
DJ = good_D_Jun.head(5)

print('###########')
data_E_Jun = data_E[data_E['支付时间'].dt.month == 5]
good_E_Jun =data_E_Jun['商品'].value_counts()
EJ = good_E_Jun.head(5)

print('###########')
data['支付时间'] = pd.to_datetime(data['支付时间'])
data_Jun = data[data['支付时间'].dt.month == 5]
good_Jun =data_Jun['商品'].value_counts()

daJ = good_Jun.head(5)

#AJ.cumsum()
#开始画图
plt.figure()
plt.subplot(231)
AJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)

plt.xlabel('售货机A销量前五商品')
plt.ylabel('销量')

plt.subplot(232)
BJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)

plt.xlabel('售货机B销量前五商品')
plt.ylabel('销量')

plt.subplot(233)
CJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)

plt.xlabel('售货机C销量前五商品')
plt.ylabel('销量')

plt.subplot(234)
DJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)
plt.xlabel('售货机D销量前五商品')
plt.ylabel('销量')

plt.subplot(235)
EJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)

plt.ylim()
plt.xlabel('售货机E销量前五商品')
plt.ylabel('销量')

plt.subplot(236)
daJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)
plt.xlabel('总销量前五商品')
plt.ylabel('销量')


plt.subplots_adjust(wspace = 0.5, hspace = 1)#调整子图间距

plt.tight_layout()
plt.savefig('2017年5月销量前5的商品销量柱状图.png', dpi=300)
plt.show()
# Out:
# ###########
# ###########
# ###########
# ###########
# ###########

# %%
data_A_Jun = data_A[data_A['支付时间'].dt.month == 6]
good_A_Jun =data_A_Jun['商品'].value_counts()
AJ = good_A_Jun.head(5)
print(AJ)
print('###########')
data_B_Jun = data_B[data_B['支付时间'].dt.month == 6]
good_B_Jun =data_B_Jun['商品'].value_counts()
BJ = good_B_Jun.head(5)
print(BJ)
print('###########')
data_C_Jun = data_C[data_C['支付时间'].dt.month == 6]
good_C_Jun =data_C_Jun['商品'].value_counts()
CJ = good_C_Jun.head(5)
print(CJ)
print('###########')
data_D_Jun = data_D[data_D['支付时间'].dt.month == 6]
good_D_Jun =data_D_Jun['商品'].value_counts()
DJ = good_D_Jun.head(5)
print(DJ)
print('###########')
data_E_Jun = data_E[data_E['支付时间'].dt.month == 6]
good_E_Jun =data_E_Jun['商品'].value_counts()
EJ = good_E_Jun.head(5)
print(EJ)
print('###########')
data['支付时间'] = pd.to_datetime(data['支付时间'])
data_Jun = data[data['支付时间'].dt.month == 6]
good_Jun =data_Jun['商品'].value_counts()

daJ = good_Jun.head(5)
print(daJ)
# Out:
# 怡宝纯净水            61
# 东鹏特饮             52
# 脉动               50
# 20g咪咪虾条马来西亚风味    48
# 250ml维他柠檬茶       44
# Name: 商品, dtype: int64
# ###########
# 怡宝纯净水          112
# 250ml维他柠檬茶      63
# 30g无穷农场盐_鸡蛋     60
# 脉动              60
# 250ml维他原味豆奶     56
# Name: 商品, dtype: int64
# ###########
# 怡宝纯净水            110
# 20g咪咪虾条马来西亚风味     68
# 250ml维他原味豆奶       64
# 脉动                58
# 250ml维他柠檬茶        56
# Name: 商品, dtype: int64
# ###########
# 30g无穷农场盐_鸡蛋      50
# 怡宝纯净水            37
# 40g双汇玉米热狗肠       34
# 20g咪咪虾条马来西亚风味    33
# 东鹏特饮             32
# Name: 商品, dtype: int64
# ###########
# 怡宝纯净水         337
# 40g双汇玉米热狗肠     90
# 东鹏特饮           59
# 伊利优酸乳          45
# 芬达330ml        44
# Name: 商品, dtype: int64
# ###########
# 怡宝纯净水         657
# 40g双汇玉米热狗肠    240
# 东鹏特饮          238
# 脉动            235
# 250ml维他柠檬茶    225
# Name: 商品, dtype: int64

# %%
#AJ.cumsum()
#开始画图
plt.figure()
plt.subplot(231)
AJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)
plt.yticks([0, 20, 40, 60, 80, 100, 120])
plt.xlabel('售货机A销量前五商品')
plt.ylabel('销量')

plt.subplot(232)
BJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)
plt.yticks([0, 20, 40, 60, 80, 100, 120])
plt.xlabel('售货机B销量前五商品')
plt.ylabel('销量')

plt.subplot(233)
CJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)
plt.yticks([0, 20, 40, 60, 80, 100, 120])
plt.xlabel('售货机C销量前五商品')
plt.ylabel('销量')

plt.subplot(234)
DJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)
plt.yticks([0, 20, 40, 60, 80, 100, 120])
plt.xlabel('售货机D销量前五商品')
plt.ylabel('销量')

plt.subplot(235)
EJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)
plt.yticks([50, 100, 150, 200, 250, 300])
plt.ylim()
plt.xlabel('售货机E销量前五商品')
plt.ylabel('销量')

plt.subplot(236)
daJ.plot(kind = 'bar')
plt.xticks(fontsize=8, rotation=60)
plt.xlabel('总销量前五商品')
plt.ylabel('销量')


plt.subplots_adjust(wspace = 0.5, hspace = 1)#调整子图间距

plt.tight_layout()
plt.savefig('2017年6月销量前5的商品销量柱状图.png', dpi=300)
plt.show()

# %%
x = range(1, 13)
plt.figure()
plt.title('每月平均每单交易额折线图')
plt.plot(x, avg_A, color='yellow',label='A ')
plt.plot(x, avg_B, color='green', label='B')
plt.plot(x, avg_C, color='red', label='C')
plt.plot(x, avg_D, color='blue', label='D')
plt.plot(x, avg_E, color='skyblue', label='E')
plt.legend() # 显示图例
plt.xlabel('月份（月）')
plt.ylabel('每月平均每单交易额（元）')
plt.savefig('每月平均每单交易额折线图.png', dpi=300)
plt.show()

# %%
x = range(1, 13)
plt.figure()
plt.title('每月日均订单量折线图')
plt.plot(x, avgDay_A, color='yellow',label='A ')
plt.plot(x, avgDay_B, color='green', label='B')
plt.plot(x, avgDay_C, color='red', label='C')
plt.plot(x, avgDay_D, color='blue', label='D')
plt.plot(x, avgDay_E, color='skyblue', label='E')
plt.legend() # 显示图例
plt.xlabel('月份（月）')
plt.ylabel('每月日均订单量（元）')
plt.savefig('每月日均订单量折线图.png', dpi=300)
plt.show()

# %%
#2.2	绘制每台售货机每月的总交易额折线图
x = range(1, 13)
plt.figure()
plt.title('每台售货机每月的交易额折线图')
plt.plot(x, AMON, color='yellow',label='A ')
plt.plot(x, BMON, color='green', label='B')
plt.plot(x, CMON, color='red', label='C')
plt.plot(x, DMON, color='blue', label='D')
plt.plot(x, EMON, color='skyblue', label='E')
plt.legend() # 显示图例
plt.xlabel('月份（月）')
plt.ylabel('每月收入（元）')
plt.savefig('每台售货机每月的总交易额折线图.png', dpi=300)
plt.show()

# %%
AM = AMON
dM = np.diff(np.array(AM))
A = dM/AM[0:11]
print(A)

BM = BMON
dM = np.diff(np.array(BM))
B = dM/BM[0:11]
print(B)

CM = CMON
dM = np.diff(np.array(CM))
C = dM/CM[0:11]
print(C)

DM = DMON
dM = np.diff(np.array(DM))
D = dM/DM[0:11]
print(D)

EM = EMON
dM = np.diff(np.array(EM))

E = dM/EM[0:11]
print(E)

plt.figure(1)





plt.subplot(321)
plt.bar(range(2,13), A)
plt.yticks([-1,-0.5,0,0.5,1,1.5])
plt.xlabel('月份')
plt.ylabel('(A)环比增长率')

plt.subplot(322)
plt.bar(range(2,13), B)
plt.yticks([-1,-0.5,0,0.5,1,1.5])
plt.xlabel('月份')
plt.ylabel('(B)环比增长率')

plt.subplot(323)
plt.bar(range(2,13), C)
plt.yticks([-1,-0.5,0,0.5,1,1.5,2.0])
plt.xlabel('月份')
plt.ylabel('(C)环比增长率')

plt.subplot(324)
plt.bar(range(2,13), D)
plt.yticks([-1,-0.5,0,0.5,1,1.5])
plt.xlabel('月份')
plt.ylabel('(D)环比增长率')

plt.subplot(325)
plt.bar(range(2,13), E)
plt.yticks([-1,-0.5,0,0.5,1,1.5])
plt.xlabel('月份')
plt.ylabel('(E)环比增长率')
plt.tight_layout()
plt.savefig('每台售货机月环比增长率柱状图.png', dpi=300)
plt.show()
# Out:
# [-0.7082202   1.0755959   0.97364104  0.87592137  0.99553925 -0.7112552
#   0.14683409  1.0025482   0.40471032 -0.17567223  0.4627145 ]
# [-0.5615172   0.5904035   1.5654033   0.49800608  1.0510432  -0.7988689
#   1.3153564   1.0497993   0.1559946   0.04060454 -0.0652603 ]
# [-0.5172204   0.25189394  2.2600102   0.15379137  1.2717328  -0.64034134
#   0.6170129   0.50775284  0.2746938  -0.10697276  0.1092388 ]
# [-0.5446466   0.8982779   1.0310874   0.4246323   0.7503448  -0.6797707
#   0.76857096  0.61645514  0.201821    0.01447885  0.27128008]
# [-0.4334259   0.6054117   1.4705375   0.5307136   0.7370943  -0.6781317
#   1.1097478   1.5368986  -0.40140614  1.106244   -0.36947143]

# %%
os.chdir('C:\\Users\\Administrator\\Desktop\\Insane TeddY')

goods_class = pd.read_csv('Pro_Data\\td2.csv', encoding = 'gbk')


#引入数据
print(goods_class[goods_class['商品'].str.contains('100g')])
print('查看数据列名', goods_class.columns.values.tolist())
L2class = goods_class['二级类'].unique()
print(L2class)
import calendar
monthRange = calendar.monthrange(2017,9)
print(monthRange[1])
# Out:
#                   商品   大类       二级类
# 0         100g*5瓶益力多   饮料       乳制品
# 1    100g越南LIPO奶味面包干  非饮料      饼干糕点
# 139       益力多100g*5瓶   饮料       乳制品
# 141  越南LIPO奶味面包干100g  非饮料      饼干糕点
# 143   100g卫龙点心面黑椒牛排味  非饮料  肉干/豆制品/蛋
# 186      100g果王咸柑桔罐装  非饮料     蜜饯/果干
# 查看数据列名 ['商品', '大类', '二级类']
# ['乳制品' '饼干糕点' '肉干/豆制品/蛋' '蜜饯/果干' '果冻/龟苓膏' '膨化食品' '坚果炒货' '糖果/巧克力' '功能饮料'
#  '植物蛋白' '茶饮料' '咖啡' '海味零食' '方便速食' '果蔬饮料' '碳酸饮料' '纸巾' '水' '香烟' '其他']
# 30

# %%
data_mer = pd.merge(data, goods_class, how='left', on=['商品'])

data_mer['支付时间'] = pd.to_datetime(data_mer['支付时间'])

#生成每月的日交易额均值
Ave_mon_pft = []
for i in L2class:
    Ave_mon_pft_i = []
    for j in range(1,13):
        data_me = data_mer[data_mer['支付时间'].dt.month == j]
        data_m = data_me[data_mer['二级类'] == i]
        nu, monthRange = calendar.monthrange(2017,j)
        re = data_m['实际金额'].sum() / monthRange
        Ave_mon_pft_i.append(re)
    
    Ave_mon_pft.append(Ave_mon_pft_i)

#列表转数组
Ave_mon_pft = np.array(Ave_mon_pft)
#保留3位小数
Ave_mon_pft = np.round(Ave_mon_pft, 3)
#print(Ave_mon_pft)
sns.set(style = "white")#设置样式

plt.figure(1)
plt.figure(1, figsize=(200,100))
cm = plt.cm.get_cmap('RdYlBu')
#这里我用0-19代替商品二级类作为纵轴，然后在替换数字为字符串
for i in range(0,len(L2class)):
        plt.scatter(range(1,13), np.array(i).repeat(12),s=Ave_mon_pft[i], c = Ave_mon_pft[i] *10 ,cmap=cm, linewidth = 0.5, marker='o' ,alpha = 0.5)
        
plt.yticks(range(0,20), L2class)
plt.xlabel('month')
plt.ylabel('二级类')
plt.colorbar()
plt.savefig('气泡图.png', dpi=300)
plt.show()
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()

# %%
PROFIT_SUM = 0
ACC = []
for i in ['A', 'B', 'C', 'D', 'E']:

    data_i = data[data['地点'] == i]
    result_i = pd.merge(data_i, goods_class, how='left', on=['商品'])
    DRK = result_i[result_i['大类'] == '饮料']
    ANDRK = result_i[result_i['大类'] == '非饮料']
    DRK_prf = DRK['实际金额'].sum()
    ANDRK_prf = ANDRK['实际金额'].sum()
    
    PROFIT = DRK_prf*0.25 + ANDRK_prf*0.2
    PROFIT = round(PROFIT, 3)
    print(PROFIT)
    ACC.append(PROFIT)
    print(i, '售货机毛利润：', PROFIT)
    PROFIT_SUM = PROFIT_SUM + PROFIT

print(PROFIT_SUM)


PIE = (ACC/PROFIT_SUM).astype('float32')
print(PIE)
def draw_pie(labels, quants):
    plt.figure(1)
    
    expl = [0.1, 0, 0, 0, 0]
    colors = ['blue', 'red', 'coral', 'green', 'yellow']
    
    plt.pie(quants, explode=expl, colors=colors, labels=labels, autopct='%1.1f%%', pctdistance=0.8, shadow=True)
    plt.title('毛利润饼图')
    plt.savefig('毛利润饼图.png', dpi=300)
    plt.show()

    
MONTH = ['A', 'B', 'C', 'D', 'E']
draw_pie(MONTH, PIE)
# Out:
# 9707.585
# A 售货机毛利润： 9707.585
# 12543.82
# B 售货机毛利润： 12543.82
# 14291.365
# C 售货机毛利润： 14291.365
# 7703.34
# D 售货机毛利润： 7703.34
# 22341.23
# E 售货机毛利润： 22341.23
# 66587.34
# [0.14578725 0.18838145 0.21462587 0.11568776 0.33551767]

# %%
data_c = data[data['地点'] == 'C']
for i in [6, 7, 8]:
    data_c_JAS = data_c[ data_c['支付时间'].dt.month == i]
    data_c_need = data_c_JAS
    data_c_need['Month'] = data_c_need['支付时间'].dt.strftime('%b%d')
    data_c_need['Hour'] = data_c_need['支付时间'].dt.strftime('%H')
    data_c_ned = data_c_need[['支付时间', 'Month', 'Hour']]

    fina = data_c_ned.set_index(['Month', 'Hour'], drop=False)
    fina['cou'] = 1
    final = fina['cou']
    finalll = final.sum(level=[0,1])
    finaly = finalll.unstack(0).fillna(0)

    # plot heatmap
    ax = sns.heatmap(finaly, cmap='rainbow')

    # turn the axis label
    for item in ax.get_yticklabels():
        item.set_rotation(0)

    for item in ax.get_xticklabels():
        item.set_rotation(45)
        
    if i == 6:
        plt.savefig('6月热力图.png', dpi=300)
    if i == 7:
        plt.savefig('7月热力图.png', dpi=300)
    if i == 8:
        plt.savefig('8月热力图.png', dpi=300)
        
    plt.show()
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in ['A', 'B', 'C', 'D', 'E']:
    data_meri = data_mer[data_mer['地点'] == i]
    data_meri = data_meri.drop(['订单号', '设备ID'], axis = 1)
    data_meri = data_meri[data_mer['大类'] == '饮料']
    drk = data_meri['商品'].value_counts()
    drinked = pd.DataFrame({'商品':drk.index, '数目':drk.values})
    
    #首先做第一步分类,按区间[0,90],[90, 360], [>360]分成滞销、适中、热销三个标签

    bin = [0,90,360,10000]
    se1=pd.cut(drinked['数目'], bin, labels=['滞销','适中','热销'])
    drinked['标签'] = se1
    
    #做第二步分类,对一些500ml饮料按区间[0,55],[55, 110], [>110]分成滞销、适中、热销三个标签
    booll = drinked['商品'].str.contains('500')
    drk_bool = drinked[booll]
    bin2 = [0,55,110,10000]
    se2=pd.cut(drk_bool['数目'], bin2, labels=['滞销','适中','热销'])


    #drinked[se2.index]=se2.values
    drinked['标签'][se2.index] =se2.values
    #print(drinked.sort_values('标签', ascending = False))
    print(drinked)
# Out:
#                       商品   数目  标签
# 0                  怡宝纯净水  531  热销
# 1                   东鹏特饮  448  热销
# 2                  阿萨姆奶茶  326  适中
# 3                     脉动  309  适中
# 4                   营养快线  255  适中
# 5                  统一冰红茶  228  适中
# 6             250ml维他柠檬茶  181  适中
# 7            250ml维他原味豆奶  176  适中
# 8                     红牛  166  适中
# 9                   统一绿茶  151  适中
# 10                   果粒橙  145  适中
# 11                 伊利优酸乳  143  适中
# 12           145ml旺仔牛奶盒装  131  适中
# 13           250ml燕塘红枣牛奶  128  适中
# 14            250ml燕塘甜牛奶  126  适中
# 15             雪碧（500ml）  123  热销
# 16           250ml燕塘原味酸奶  112  适中
# 17            王老吉（500ml）  108  适中
# 18                 银鹭八宝粥  103  适中
# 19           可口可乐（500ml）  101  适中
# 20         268ml雀巢咖啡丝滑拿铁   91  适中
# 21                 伊利纯牛奶   90  滞销
# 22                 雪碧最新款   78  滞销
# 23        330ml伊利畅意乳酸菌原味   74  滞销
# 24               250ml红牛   71  滞销
# 25           450ml美汁源果粒橙   69  滞销
# 26          250ml维他奶巧克力味   69  滞销
# 27                王老吉（罐）   68  滞销
# 28               雪碧330ml   67  滞销
# 29          500ml统一阿萨姆奶茶   65  适中
# ..                   ...  ...  ..
# 82                燕塘原味酸奶    6  滞销
# 83   250ml维他椰子植物蛋白饮料9374    6  滞销
# 84                  小茗同学    6  滞销
# 85                冰红茶（罐）    6  滞销
# 86                脉动（青柠）    5  滞销
# 87             乐虎（380ml）    5  滞销
# 88          可口可乐330ml（罐）    5  滞销
# 89                  天地一号    4  滞销
# 90                  经典奶茶    4  滞销
# 91                   加多宝    4  滞销
# 92          13g雀巢咖啡1+2特浓    4  滞销
# 93              500ML宝矿力    4  滞销
# 94                   商品2    4  滞销
# 95             维他奶（巧克力味）    4  滞销
# 96          500ml康师傅冰糖雪梨    4  滞销
# 97           500ml统一冰糖雪梨    4  滞销
# 98          500ml恒大冰泉矿泉水    3  滞销
# 99              拿铁咖啡（统一）    3  滞销
# 100        维他柠檬茶330ml（罐）    3  滞销
# 101            旺仔牛奶145ml    3  滞销
# 102               珠江纯生啤酒    3  滞销
# 103          145ml旺仔牛奶罐装    2  滞销
# 104                 健能酸奶    2  滞销
# 105                  商品1    2  滞销
# 106                安慕希酸奶    2  滞销
# 107              娃哈哈红枣酸奶    2  滞销
# 108          250ml香满楼纯牛奶    2  滞销
# 109           脉动（椰子菠萝口味）    1  滞销
# 110        小茗同学冷泡茶（乳酸菌味）    1  滞销
# 111                  芦荟汁    1  滞销
#
# [112 rows x 3 columns]
#                       商品    数目  标签
# 0                  怡宝纯净水  1342  热销
# 1                   东鹏特饮   488  热销
# 2                  阿萨姆奶茶   457  热销
# 3                     脉动   431  热销
# 4                   营养快线   425  热销
# 5                  统一冰红茶   334  适中
# 6             王老吉（500ml）   310  热销
# 7                    果粒橙   245  适中
# 8             250ml维他柠檬茶   236  适中
# 9            250ml维他原味豆奶   229  适中
# 10             可口可乐330ml   212  适中
# 11                  统一绿茶   209  适中
# 12                王老吉（罐）   201  适中
# 13               芬达330ml   198  适中
# 14                    红牛   198  适中
# 15                 伊利优酸乳   179  适中
# 16                 伊利纯牛奶   175  适中
# 17           145ml旺仔牛奶盒装   172  适中
# 18                 雪碧最新款   139  适中
# 19             雪碧（500ml）   137  热销
# 20            250ml燕塘甜牛奶   131  适中
# 21           250ml燕塘原味酸奶   130  适中
# 22                 银鹭八宝粥   120  适中
# 23               可口可乐最新款   116  适中
# 24           250ml燕塘红枣牛奶   114  适中
# 25               雪碧330ml   103  适中
# 26             百事可乐500ml   102  适中
# 27               250ml红牛    99  适中
# 28          250ml维他奶巧克力味    95  适中
# 29         268ml雀巢咖啡丝滑拿铁    94  适中
# ..                   ...   ...  ..
# 85         340ml蒙牛优益C乳酸菌     5  滞销
# 86           优益C活菌型乳酸菌饮品     5  滞销
# 87                   芦荟汁     5  滞销
# 88           205ml安慕希蓝莓味     5  滞销
# 89       480ml小茗同学冷泡溜溜哒茶     4  滞销
# 90                  农夫果园     4  滞销
# 91             维他奶（巧克力味）     4  滞销
# 92             旺仔牛奶145ml     4  滞销
# 93             百事可乐330ml     4  滞销
# 94                燕塘原味酸奶     4  滞销
# 95                珠江纯生啤酒     4  滞销
# 96          13g雀巢咖啡1+2特浓     3  滞销
# 97                 怡宝矿泉水     3  滞销
# 98           145ml旺仔牛奶罐装     3  滞销
# 99                    雪碧     3  滞销
# 100        维他柠檬茶330ml（罐）     3  滞销
# 101          250ml香满楼纯牛奶     2  滞销
# 102                  商品1     2  滞销
# 103                 小茗同学     2  滞销
# 104           小茗同学（青柠红茶）     2  滞销
# 105          500ml统一冰糖雪梨     2  滞销
# 106      330ml伊利畅意乳酸菌草莓味     2  滞销
# 107                  商品2     2  滞销
# 108         500ml恒大冰泉矿泉水     1  滞销
# 109                 商品14     1  滞销
# 110             拿铁咖啡（统一）     1  滞销
# 111           脉动（椰子菠萝口味）     1  滞销
# 112              娃哈哈红枣酸奶     1  滞销
# 113  250ml维他椰子植物蛋白饮料9374     1  滞销
# 114        小茗同学冷泡茶（乳酸菌味）     1  滞销
#
# [115 rows x 3 columns]
#                       商品   数目  标签
# 0                  怡宝纯净水  999  热销
# 1                     脉动  759  热销
# 2                   东鹏特饮  525  热销
# 3                  阿萨姆奶茶  456  热销
# 4                   营养快线  435  热销
# 5                 王老吉（罐）  402  热销
# 6                  统一冰红茶  394  热销
# 7                    果粒橙  328  适中
# 8                芬达330ml  271  适中
# 9                  雪碧最新款  259  适中
# 10                 伊利优酸乳  258  适中
# 11            250ml维他柠檬茶  255  适中
# 12                  统一绿茶  246  适中
# 13            王老吉（500ml）  238  热销
# 14                    红牛  231  适中
# 15             可口可乐330ml  219  适中
# 16           250ml维他原味豆奶  217  适中
# 17                    怡宝  182  适中
# 18                 银鹭八宝粥  166  适中
# 19           250ml燕塘原味酸奶  134  适中
# 20           250ml燕塘红枣牛奶  129  适中
# 21            250ml燕塘甜牛奶  129  适中
# 22                 伊利纯牛奶  127  适中
# 23           145ml旺仔牛奶盒装  127  适中
# 24               可口可乐最新款  125  适中
# 25               250ml红牛  119  适中
# 26         268ml雀巢咖啡丝滑拿铁   95  适中
# 27             雪碧（500ml）   82  适中
# 28          500ml统一阿萨姆奶茶   80  适中
# 29                   维他奶   79  滞销
# ..                   ...  ...  ..
# 84                 怡宝矿泉水    7  滞销
# 85             乐虎（380ml）    6  滞销
# 86         小茗同学冷泡茶（乳酸菌味）    5  滞销
# 87           205ml安慕希蓝莓味    5  滞销
# 88           500ml营养快线原味    5  滞销
# 89          13g雀巢咖啡1+2特浓    5  滞销
# 90                珠江纯生啤酒    5  滞销
# 91           500ml统一冰糖雪梨    4  滞销
# 92                 安慕希酸奶    4  滞销
# 93            益力多100g*5瓶    4  滞销
# 94              500ML宝矿力    4  滞销
# 95           250ml香满楼纯牛奶    4  滞销
# 96            小茗同学（青柠红茶）    3  滞销
# 97         250ml维他奶黑豆奶饮品    3  滞销
# 98                   商品2    3  滞销
# 99          可口可乐330ml（罐）    3  滞销
# 100                 天地一号    3  滞销
# 101           脉动（椰子菠萝口味）    2  滞销
# 102          优益C活菌型乳酸菌饮品    2  滞销
# 103            百事可乐330ml    2  滞销
# 104                雪力矿泉水    2  滞销
# 105                 健能酸奶    2  滞销
# 106         500ml恒大冰泉矿泉水    2  滞销
# 107             拿铁咖啡（统一）    2  滞销
# 108             维他奶黑豆奶饮品    2  滞销
# 109      330ml伊利畅意乳酸菌草莓味    2  滞销
# 110              娃哈哈红枣酸奶    2  滞销
# 111                  芦荟汁    1  滞销
# 112                 商品14    1  滞销
# 113  250ml维他椰子植物蛋白饮料9374    1  滞销
#
# [114 rows x 3 columns]
#                       商品   数目  标签
# 0                   东鹏特饮  411  热销
# 1                  怡宝纯净水  387  热销
# 2                  阿萨姆奶茶  365  热销
# 3                   营养快线  319  适中
# 4                  统一冰红茶  309  适中
# 5                     脉动  283  适中
# 6                   统一绿茶  188  适中
# 7                     红牛  180  适中
# 8                  雪碧最新款  178  适中
# 9                 王老吉（罐）  177  适中
# 10           可口可乐（500ml）  176  热销
# 11                   果粒橙  168  适中
# 12               可口可乐最新款  144  适中
# 13             雪碧（500ml）  132  热销
# 14            250ml维他柠檬茶  109  适中
# 15                 伊利优酸乳  102  适中
# 16           250ml维他原味豆奶   96  适中
# 17            王老吉（500ml）   87  适中
# 18                美年达（罐）   83  滞销
# 19                 银鹭八宝粥   83  滞销
# 20           145ml旺仔牛奶盒装   81  滞销
# 21                 伊利纯牛奶   81  滞销
# 22            250ml燕塘甜牛奶   77  滞销
# 23           250ml燕塘原味酸奶   72  滞销
# 24               250ml红牛   68  滞销
# 25                 维他柠檬茶   65  滞销
# 26           250ml燕塘红枣牛奶   64  滞销
# 27             600ml可口可乐   63  滞销
# 28                   维他奶   56  滞销
# 29             可口可乐330ml   54  滞销
# ..                   ...  ...  ..
# 75                    雪碧    3  滞销
# 76           500ml营养快线原味    3  滞销
# 77         250ml维他奶黑豆奶饮品    3  滞销
# 78          500ml康师傅冰糖雪梨    3  滞销
# 79           250ml统一麦香奶茶    2  滞销
# 80           205ml安慕希蓝莓味    2  滞销
# 81                    乐虎    2  滞销
# 82           500ml统一冰糖雪梨    2  滞销
# 83             维他奶（巧克力味）    2  滞销
# 84                   商品2    2  滞销
# 85       250ml维他椰子植物蛋白饮料    2  滞销
# 86                冰红茶（罐）    2  滞销
# 87                 燕塘甜牛奶    2  滞销
# 88                  旺仔牛奶    2  滞销
# 89                  农夫果园    2  滞销
# 90          可口可乐330ml（罐）    2  滞销
# 91      250ml维他椰子味豆奶7716    2  滞销
# 92             可乐（500ml）    2  滞销
# 93                  经典奶茶    1  滞销
# 94         小茗同学冷泡茶（乳酸菌味）    1  滞销
# 95              500ML宝矿力    1  滞销
# 96          500ml恒大冰泉矿泉水    1  滞销
# 97           145ml旺仔牛奶罐装    1  滞销
# 98                脉动（青柠）    1  滞销
# 99           250ml香满楼纯牛奶    1  滞销
# 100                  芦荟汁    1  滞销
# 101                  商品1    1  滞销
# 102  250ml维他椰子植物蛋白饮料9374    1  滞销
# 103           脉动（椰子菠萝口味）    1  滞销
# 104            旺仔牛奶145ml    1  滞销
#
# [105 rows x 3 columns]
#                       商品    数目  标签
# 0                  怡宝纯净水  1705  热销
# 1                     脉动   996  热销
# 2                   营养快线   805  热销
# 3                  阿萨姆奶茶   792  热销
# 4                   东鹏特饮   709  热销
# 5                  统一冰红茶   626  热销
# 6                   统一绿茶   490  热销
# 7                    果粒橙   470  热销
# 8             王老吉（500ml）   417  热销
# 9                 王老吉（罐）   410  热销
# 10            250ml维他柠檬茶   397  热销
# 11           250ml维他原味豆奶   391  热销
# 12               芬达330ml   382  热销
# 13                 伊利优酸乳   375  热销
# 14                 雪碧最新款   309  适中
# 15                    红牛   289  适中
# 16           250ml燕塘原味酸奶   249  适中
# 17             可口可乐330ml   244  适中
# 18                 伊利纯牛奶   241  适中
# 19            250ml燕塘甜牛奶   232  适中
# 20           145ml旺仔牛奶盒装   228  适中
# 21                 银鹭八宝粥   220  适中
# 22           250ml燕塘红枣牛奶   206  适中
# 23           可口可乐（500ml）   202  热销
# 24         268ml雀巢咖啡丝滑拿铁   197  适中
# 25               雪碧330ml   173  适中
# 26               250ml红牛   172  适中
# 27             雪碧（500ml）   172  热销
# 28                 维他柠檬茶   169  适中
# 29          500ml统一阿萨姆奶茶   158  热销
# ..                   ...   ...  ..
# 83       250ml维他椰子植物蛋白饮料    12  滞销
# 84               阿萨姆煎茶奶绿    11  滞销
# 85         80g香飘飘椰果奶茶麦香味    11  滞销
# 86           205ml安慕希蓝莓味    10  滞销
# 87                  小茗同学    10  滞销
# 88           500ml营养快线原味    10  滞销
# 89            脉动（椰子菠萝口味）     9  滞销
# 90          500ml恒大冰泉矿泉水     9  滞销
# 91              拿铁咖啡（统一）     8  滞销
# 92              500ML宝矿力     7  滞销
# 93                 安慕希酸奶     5  滞销
# 94         250ml维他奶黑豆奶饮品     5  滞销
# 95          13g雀巢咖啡1+2特浓     4  滞销
# 96          可口可乐330ml（罐）     3  滞销
# 97       330ml伊利畅意乳酸菌草莓味     3  滞销
# 98           500ml统一冰糖雪梨     3  滞销
# 99      250ml维他椰子味豆奶7716     3  滞销
# 100                  商品1     3  滞销
# 101                 经典奶茶     2  滞销
# 102  250ml维他椰子植物蛋白饮料9374     2  滞销
# 103        维他柠檬茶330ml（罐）     2  滞销
# 104            百事可乐330ml     2  滞销
# 105        340ml蒙牛优益C乳酸菌     2  滞销
# 106               冰红茶（罐）     2  滞销
# 107            乐虎（380ml）     2  滞销
# 108                  商品2     1  滞销
# 109        小茗同学冷泡茶（乳酸菌味）     1  滞销
# 110           小茗同学（青柠红茶）     1  滞销
# 111             维他奶黑豆奶饮品     1  滞销
# 112               珠江纯生啤酒     1  滞销
#
# [113 rows x 3 columns]
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
data_merA = data_mer[data_mer['地点'] == 'A']
data_merA['支付时间'] = pd.to_datetime(data_merA['支付时间'])


group = data_merA.groupby(['大类', data_merA['支付时间'].dt.strftime('%m')])
a = group.sum()
b = a['实际金额']
from sklearn import linear_model
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingClassifier    
# Create linear regression object
regr = SVR()
for i in ['非饮料','饮料']:
    print('2018年1月A商品销售预测:')
    #Train the model using the training sets
    regr.fit(np.matrix(range(1,13)).T, np.matrix(b[i].values).T)
    print(i ,':', regr.predict(1))
    print('对比2017年1月：')
    print(b[i][0])
# Out:
# 2018年1月A商品销售预测:
# 非饮料 : [1279.11368162]
# 对比2017年1月：
# 792.4
# 2018年1月A商品销售预测:
# 饮料 : [1468.4636814]
# 对比2017年1月：
# 717.3
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# F:\Anaconda\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
